# %% [markdown]
# # To train the Object detection Model:

# %%
from ultralytics import YOLO

# # Load a model
model = YOLO('yolov8n.pt')  # load a pretrained model (recommended for training)

# # Train the model with 2 GPUs
results = model.train(data='data.yaml', epochs=200, imgsz=640)
# Out:
# yolo\engine\trainer: task=detect, mode=train, model=yolov8n.yaml, data=data.yaml, epochs=200, patience=50, batch=16, imgsz=640, save=True, cache=False, device=None, workers=8, project=None, name=None, exist_ok=False, pretrained=False, optimizer=SGD, verbose=False, seed=0, deterministic=True, single_cls=False, image_weights=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, overlap_mask=True, mask_ratio=4, dropout=False, val=True, save_json=False, save_hybrid=False, conf=0.001, iou=0.7, max_det=300, half=True, dnn=False, plots=True, source=ultralytics/assets/, show=False, save_txt=False, save_conf=False, save_crop=False, hide_labels=False, hide_conf=False, vid_stride=1, line_thickness=3, visualize=False, augment=False, agnostic_nms=False, retina_masks=False, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=
# ...

# %% [markdown]
# # Test Object Detection Model:

# %%
from ultralytics import YOLO

# Load a pretrained YOLOv8n model
model = YOLO('runs/detect/train2/weights/best.pt')

# Run inference on 'bus.jpg' with arguments
model.predict('images.mp4', save=True, imgsz=320, conf=0.2)
# Out:
# Ultralytics YOLOv8.0.3  Python-3.11.7 torch-2.2.2+cpu CPU
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# video 1/1 (1/500) C:\Users\Astha Singh\Automatic-Number-Plate-Recognition--ANPR--main\images.mp4: 256x320 1 licence, 108.6ms
# video 1/1 (2/500) C:\Users\Astha Singh\Automatic-Number-Plate-Recognition--ANPR--main\images.mp4: 256x320 1 licence, 71.0ms
# video 1/1 (3/500) C:\Users\Astha Singh\Automatic-Number-Plate-Recognition--ANPR--main\images.mp4: 256x320 1 licence, 67.5ms
# video 1/1 (4/500) C:\Users\Astha Singh\Automatic-Number-Plate-Recognition--ANPR--main\images.mp4: 256x320 1 licence, 69.0ms
# video 1/1 (5/500) C:\Users\Astha Singh\Automatic-Number-Plate-Recognition--ANPR--main\images.mp4: 256x320 1 licence, 63.0ms
# video 1/1 (6/500) C:\Users\Astha Singh\Automatic-Number-Plate-Recognition--ANPR--main\images.mp4: 256x320 1 licence, 68.0ms
# ...

# %% [markdown]
# # Recognize License plate after Detecting  using easy-ocr

# %%
#!pip install easyocr

# %%
# !python predict_modified.py model='runs/detect/train2/weights/best.pt' source='"C:\Users\Astha Singh\OneDrive - Army Institute of Technology\Desktop\Untitled Export"'
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Ultralytics YOLOv8.0.3  Python-3.11.7 torch-2.2.2+cpu CPU
# Fusing layers...
# Model summary: 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# image 1/11 C:\Users\Astha Singh\OneDrive - Army Institute of Technology\Desktop\Untitled Export\20240310-pexels-alfred-rohlin-11213779.jpg: 640x512 1 licence, 103.8ms
# image 2/11 C:\Users\Astha Singh\OneDrive - Army Institute of Technology\Desktop\Untitled Export\automobile-1846297_1920.jpg: 448x640 1 licence, 98.6ms
# image 3/11 C:\Users\Astha Singh\OneDrive - Army Institute of Technology\Desktop\Untitled Export\car-6366999_1920.jpg: 448x640 1 licence, 79.6ms
# image 4/11 C:\Users\Astha Singh\OneDrive - Army Institute of Technology\Desktop\Untitled Export\ferrari-188954_1920.jpg: 480x640 1 licence, 133.6ms
# ...
